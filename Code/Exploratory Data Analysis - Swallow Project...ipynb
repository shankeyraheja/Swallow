# %% [markdown]
# # Exploratory Data Analysis- Detection of Swallowing Disorders

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import ExcelWriter
import os
import numpy as np
import random
plt.style.use("seaborn")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sns
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

# %% [markdown]
# ### Loading the dataset

# %%
healthy = pd.read_excel("D:/DATA SCIENCE/INTERNSHIP PROJECT/Modelling/HealthySamples.xlsx")
healthy = healthy[healthy["Sample status"] == "Perfect"]
healthy["Swallow_type"] = "healthy"
unhealthy = pd.read_excel("D:/DATA SCIENCE/INTERNSHIP PROJECT/Modelling/UnHealthySamples.xlsx")
unhealthy = unhealthy[unhealthy["Sample status"] == "Perfect"]
unhealthy["Swallow_type"] = "unhealthy"
data = healthy.append(unhealthy)[["Patient", "Sensor1_max", "Sensor2_max", "Sensor3_min", "Latency", "UES_start", "UES_end", "UES_Duration", "Swallow_type"]]
data["Label"] = np.where(data["Swallow_type"] == "healthy", 0, 1)
data
# Out:
#            Patient  Sensor1_max  Sensor2_max  Sensor3_min  Latency  UES_start  \
# 0    Control 1.txt   192.279698   113.474479   -20.601968   -0.028   1552.752
# 1    Control 1.txt   167.821012    98.336004   -11.776150   -0.028   1782.184
# 2    Control 1.txt   171.739528   249.844358   -24.181735   -0.036    611.556
# 3    Control 1.txt   200.377661   107.578393   -16.358434   -0.092   2333.764
# 4    Control 1.txt   193.675898   105.770199   -25.335317   -0.172   1697.164
# ..             ...          ...          ...          ...      ...        ...
# 194      HD11A.txt   114.937700   101.913100   -27.384550    0.211    117.157
# 195      HD11A.txt   195.568900    97.228870   -14.957330    0.200    163.116
# 196      HD11A.txt   200.185000   116.615400    -9.014693   -0.042    124.009
# 197      HD11B.txt   209.113400    79.385630   -12.359970    0.192     61.255
# 201      HD11B.txt   309.871200    59.288520    -9.540810    0.110     10.308
#
#       UES_end  UES_Duration Swallow_type  Label
# 0    1553.392         0.640      healthy      0
# 1    1782.896         0.712      healthy      0
# 2     612.284         0.728      healthy      0
# 3    2334.412         0.648      healthy      0
# 4    1697.784         0.620      healthy      0
# ..        ...           ...          ...    ...
# 194   117.828         0.671    unhealthy      1
# 195   164.111         0.995    unhealthy      1
# 196   124.538         0.529    unhealthy      1
# 197    61.856         0.601    unhealthy      1
# 201    10.866         0.558    unhealthy      1
#
# [244 rows x 10 columns]

# %% [markdown]
# ### Descriptive Statistics of a dataset

# %% [markdown]
# #### Healthy Class

# %%
healthy[["Sensor1_max", "Sensor2_max", "Sensor3_min", "Latency", "UES_Duration"]].describe()
# Out:
#        Sensor1_max  Sensor2_max  Sensor3_min     Latency  UES_Duration
# count   124.000000   124.000000   124.000000  124.000000    124.000000
# mean    124.158939   129.857740    -9.502119    0.145363      0.845387
# std      44.465992    53.531787     7.791889    0.128389      0.222639
# min      80.599680    44.151980   -33.376059   -0.172000      0.436000
# 25%      92.439345    89.732204   -13.897917    0.056000      0.664000
# 50%     110.516137   119.357977    -9.127947    0.150000      0.828000
# 75%     137.118334   161.465438    -3.650721    0.239250      0.981000
# max     274.703593   250.000000     8.228428    0.532000      1.892000

# %% [markdown]
# #### Unhealthy Class

# %%
unhealthy[["Sensor1_max", "Sensor2_max", "Sensor3_min", "Latency", "UES_Duration"]].describe()
# Out:
#        Sensor1_max  Sensor2_max  Sensor3_min     Latency  UES_Duration
# count   120.000000   120.000000   120.000000  120.000000    120.000000
# mean    144.082960   145.538535   -13.641965    0.159658      0.814517
# std      51.947881    79.275492     7.535588    0.103103      0.199220
# min      80.756810    47.114770   -48.677570   -0.142000      0.420000
# 25%      98.738570    88.117125   -17.293390    0.104500      0.671000
# 50%     134.162300   127.453150   -12.117235    0.166500      0.786500
# 75%     170.505650   174.013475    -8.784615    0.217500      0.955000
# max     309.871200   435.149900     1.642600    0.573000      1.601000

# %% [markdown]
# ## Histogram of Independent features for Healthy Samples

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2)
# plt.subplots()
f = plt.figure(figsize=(15,6))
f1 = plt.figure(figsize=(15,6))
f2 = plt.figure(figsize=(15,6))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax3 = f1.add_subplot(121)
ax4 = f1.add_subplot(122)
ax5 = f2.add_subplot(122)
# plt.subplot2grid((3,3), (0,0), colspan=3)
# healthy[["Sensor1_max", "Sensor2_max", "Sensor3_min", "Latency", "UES_Duration"]].hist(bins = 10, figsize=(15, 8))
ax.hist(healthy["Sensor1_max"], bins = 30)
ax.set(xlabel='Sensor1_max', ylabel='Frequency')
ax2.hist(healthy["Sensor2_max"], bins = 30)
ax2.set(xlabel='Sensor2_max', ylabel='Frequency')
ax3.hist(healthy["Sensor3_min"], bins = 30)
ax3.set(xlabel='Sensor3_min', ylabel='Frequency')
ax4.hist(healthy["Latency"], bins = 30)
ax4.set(xlabel='Latency', ylabel='Frequency')
ax5.hist(healthy["UES_Duration"], bins = 30)
ax5.set(xlabel='UES_Duration', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'UES_Duration')]

# %% [markdown]
# ## Density Plots of Independent features for healthy Samples

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
f, axes1 = plt.subplots(1, 2,figsize=(15,5))
f, axes2 = plt.subplots(1, 2,figsize=(15,5))
axes2[0].set(ylabel="Probability Density")
axes[0].set(ylabel="Probability Density")
axes[1].set(ylabel="Probability Density")
axes1[0].set(ylabel="Probability Density")
axes1[1].set(ylabel="Probability Density")
axes2[0].xaxis.label.set_size(15)
axes2[0].yaxis.label.set_size(15)
axes[0].xaxis.label.set_size(15)
axes[0].yaxis.label.set_size(15)
axes[1].xaxis.label.set_size(15)
axes[1].yaxis.label.set_size(15)
axes1[0].xaxis.label.set_size(15)
axes1[0].yaxis.label.set_size(15)
axes1[1].xaxis.label.set_size(15)
axes1[1].yaxis.label.set_size(15)
sns.distplot(healthy["Sensor1_max"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes[0])
sns.distplot(healthy["Sensor2_max"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes[1])
sns.distplot(healthy["Sensor3_min"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes1[0])
sns.distplot(healthy["Latency"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes1[1])
sns.distplot(healthy["UES_Duration"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes2[0])

# %% [markdown]
# ## Histogram of Independent features for UnHealthy Samples

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2)
# plt.subplots()
f = plt.figure(figsize=(15,6))
f1 = plt.figure(figsize=(15,6))
f2 = plt.figure(figsize=(15,6))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax3 = f1.add_subplot(121)
ax4 = f1.add_subplot(122)
ax5 = f2.add_subplot(122)
# plt.subplot2grid((3,3), (0,0), colspan=3)
# healthy[["Sensor1_max", "Sensor2_max", "Sensor3_min", "Latency", "UES_Duration"]].hist(bins = 10, figsize=(15, 8))
ax.hist(unhealthy["Sensor1_max"], bins = 30)
ax.set(xlabel='Sensor1_max', ylabel='Frequency')
ax2.hist(unhealthy["Sensor2_max"], bins = 30)
ax2.set(xlabel='Sensor2_max', ylabel='Frequency')
ax3.hist(unhealthy["Sensor3_min"], bins = 30)
ax3.set(xlabel='Sensor3_min', ylabel='Frequency')
ax4.hist(unhealthy["Latency"], bins = 30)
ax4.set(xlabel='Latency', ylabel='Frequency')
ax5.hist(unhealthy["UES_Duration"], bins = 30)
ax5.set(xlabel='UES_Duration', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'UES_Duration')]

# %% [markdown]
# ## Density Plots of Independent features for healthy Samples

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
f, axes1 = plt.subplots(1, 2,figsize=(15,5))
f, axes2 = plt.subplots(1, 2,figsize=(15,5))
axes2[0].set(ylabel="Probability Density")
axes[0].set(ylabel="Probability Density")
axes[1].set(ylabel="Probability Density")
axes1[0].set(ylabel="Probability Density")
axes1[1].set(ylabel="Probability Density")
axes2[0].xaxis.label.set_size(15)
axes2[0].yaxis.label.set_size(15)
axes[0].xaxis.label.set_size(15)
axes[0].yaxis.label.set_size(15)
axes[1].xaxis.label.set_size(15)
axes[1].yaxis.label.set_size(15)
axes1[0].xaxis.label.set_size(15)
axes1[0].yaxis.label.set_size(15)
axes1[1].xaxis.label.set_size(15)
axes1[1].yaxis.label.set_size(15)
sns.distplot(unhealthy["Sensor1_max"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes[0])
sns.distplot(unhealthy["Sensor2_max"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes[1])
sns.distplot(unhealthy["Sensor3_min"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes1[0])
sns.distplot(unhealthy["Latency"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes1[1])
sns.distplot(unhealthy["UES_Duration"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes2[0])

# %% [markdown]
# ### Correlation matrix of Independent variables

# %%
corr = data[["Sensor1_max", "Sensor2_max", "Sensor3_min", "Latency", "UES_Duration"]].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f9000630_6738_11eb_b50a_4485006ef15drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow0_col1 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow0_col3 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow1_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow1_col3 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow1_col4 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow2_col4 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow3_col0 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow3_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow3_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow3_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow4_col0 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow4_col1 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow4_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow4_col3 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_f9000630_6738_11eb_b50a_4485006ef15drow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_f9000630_6738_11eb_b50a_4485006ef15d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sensor1_max</th>        <th class="col_heading level0 col1" >Sensor2_max</th>        <th class="col_heading level0 col2" >Sensor3_min</th>        <th class="col_heading level0 col3" >Latency</th>        <th class="col_heading level0 col4" >UES_Duration</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9000630_6738_11eb_b50a_4485006ef15dlevel0_row0" class="row_heading level0 row0" >Sensor1_max</th>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow0_col1" class="data row0 col1" >-0.0346022</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow0_col2" class="data row0 col2" >-0.038871</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow0_col3" class="data row0 col3" >0.149575</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow0_col4" class="data row0 col4" >0.0296155</td>
#             </tr>
#             <tr>
#                         <th id="T_f9000630_6738_11eb_b50a_4485006ef15dlevel0_row1" class="row_heading level0 row1" >Sensor2_max</th>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow1_col0" class="data row1 col0" >-0.0346022</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow1_col2" class="data row1 col2" >-0.124292</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow1_col3" class="data row1 col3" >0.0283056</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow1_col4" class="data row1 col4" >0.056447</td>
#             </tr>
#             <tr>
#                         <th id="T_f9000630_6738_11eb_b50a_4485006ef15dlevel0_row2" class="row_heading level0 row2" >Sensor3_min</th>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow2_col0" class="data row2 col0" >-0.038871</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow2_col1" class="data row2 col1" >-0.124292</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow2_col3" class="data row2 col3" >-0.0584012</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow2_col4" class="data row2 col4" >0.063469</td>
#             </tr>
#             <tr>
#                         <th id="T_f9000630_6738_11eb_b50a_4485006ef15dlevel0_row3" class="row_heading level0 row3" >Latency</th>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow3_col0" class="data row3 col0" >0.149575</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow3_col1" class="data row3 col1" >0.0283056</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow3_col2" class="data row3 col2" >-0.0584012</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow3_col4" class="data row3 col4" >0.316552</td>
#             </tr>
#             <tr>
#                         <th id="T_f9000630_6738_11eb_b50a_4485006ef15dlevel0_row4" class="row_heading level0 row4" >UES_Duration</th>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow4_col0" class="data row4 col0" >0.0296155</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow4_col1" class="data row4 col1" >0.056447</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow4_col2" class="data row4 col2" >0.063469</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow4_col3" class="data row4 col3" >0.316552</td>
#                         <td id="T_f9000630_6738_11eb_b50a_4485006ef15drow4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
f, axes1 = plt.subplots(1, 2,figsize=(15,5))
f, axes2 = plt.subplots(1, 2,figsize=(15,5))
axes2[0].set(ylabel="Probability Density")
axes[0].set(ylabel="Probability Density")
axes[1].set(ylabel="Probability Density")
axes1[0].set(ylabel="Probability Density")
axes1[1].set(ylabel="Probability Density")
axes2[0].xaxis.label.set_size(15)
axes2[0].yaxis.label.set_size(15)
axes[0].xaxis.label.set_size(15)
axes[0].yaxis.label.set_size(15)
axes[1].xaxis.label.set_size(15)
axes[1].yaxis.label.set_size(15)
axes1[0].xaxis.label.set_size(15)
axes1[0].yaxis.label.set_size(15)
axes1[1].xaxis.label.set_size(15)
axes1[1].yaxis.label.set_size(15)
sns.distplot(data["Sensor1_max"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes[0])
sns.distplot(data["Sensor2_max"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes[1])
sns.distplot(data["Sensor3_min"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes1[0])
sns.distplot(data["Latency"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes1[1])
sns.distplot(data["UES_Duration"], hist=True, kde=True, 
            bins=30,color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, ax=axes2[0])
